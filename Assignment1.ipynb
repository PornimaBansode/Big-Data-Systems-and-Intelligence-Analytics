# %% [markdown]
# # PART A

# %%
#importing of dataset

# %%
import csv
import pandas as pd
dataset = pd.read_csv('dataset.csv',sep=',')
dataset.head(10)
# Out:
#          date                time username  wrist  activity  acceleration_x  \
# 0  30-06-2017  13:51:15:847724020   viktor      0         0          0.2650
# 1  30-06-2017  13:51:16:246945023   viktor      0         0          0.6722
# 2  30-06-2017  13:51:16:446233987   viktor      0         0          0.4399
# 3  30-06-2017  13:51:16:646117985   viktor      0         0          0.3031
# 4  30-06-2017  13:51:16:846738994   viktor      0         0          0.4814
# 5  30-06-2017   13:51:17:46806991   viktor      0         0          0.4044
# 6  30-06-2017  13:51:17:246767997   viktor      0         0          0.6320
# 7  30-06-2017  13:51:17:446569025   viktor      0         0          0.6670
# 8  30-06-2017  13:51:17:646152973   viktor      0         0          0.2704
# 9  30-06-2017  13:51:17:846502006   viktor      0         0          0.4690
#
#    acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# ...

# %%
#Data cleaning
import csv
import pandas as pd
dataset = pd.read_csv('dataset.csv',sep=',')
dataset.head()
dataset.isnull().sum()
# Out:
# date              0
# time              0
# username          0
# wrist             0
# activity          0
# acceleration_x    2
# acceleration_y    3
# acceleration_z    0
# gyro_x            0
# gyro_y            0
# gyro_z            0
# dtype: int64

# %%
#The above values show the number of missing values present in each column

# %%
#removing the bad data(removing the NaN value and replacing it with the mean)

from pandas import read_csv
import numpy
dataset = read_csv('dataset.csv',low_memory=False)
dataset["acceleration_x"].fillna(dataset["acceleration_x"].mean(), inplace=True)
dataset["acceleration_y"].fillna(dataset["acceleration_y"].mean(), inplace=True)
dataset
# Out:
#              date                time username  wrist  activity  \
# 0      30-06-2017  13:51:15:847724020   viktor      0         0
# 1      30-06-2017  13:51:16:246945023   viktor      0         0
# 2      30-06-2017  13:51:16:446233987   viktor      0         0
# 3      30-06-2017  13:51:16:646117985   viktor      0         0
# 4      30-06-2017  13:51:16:846738994   viktor      0         0
# 5      30-06-2017   13:51:17:46806991   viktor      0         0
# 6      30-06-2017  13:51:17:246767997   viktor      0         0
# 7      30-06-2017  13:51:17:446569025   viktor      0         0
# 8      30-06-2017  13:51:17:646152973   viktor      0         0
# 9      30-06-2017  13:51:17:846502006   viktor      0         0
# 10     30-06-2017   13:51:18:46802997   viktor      0         0
# 11     30-06-2017  13:51:18:246815025   viktor      0         0
# 12     30-06-2017  13:51:18:446740984   viktor      0         0
# 13     30-06-2017  13:51:18:646052002   viktor      0         0
# ...

# %%
#check if missing values are replaced
dataset.head()
dataset.isnull().sum()
# Out:
# date              0
# time              0
# username          0
# wrist             0
# activity          0
# acceleration_x    0
# acceleration_y    0
# acceleration_z    0
# gyro_x            0
# gyro_y            0
# gyro_z            0
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
#Summary statistics
dataset.describe()
# Out:
#               wrist      activity  acceleration_x  acceleration_y  \
# count  88588.000000  88588.000000    88588.000000    88588.000000
# mean       0.522170      0.500801       -0.074748       -0.562574
# std        0.499511      0.500002        1.009210        0.658452
# min        0.000000      0.000000       -5.350500       -3.299000
# 25%        0.000000      0.000000       -0.381800       -1.033500
# 50%        1.000000      1.000000       -0.059500       -0.759100
# 75%        1.000000      1.000000        0.355500       -0.241775
# max        1.000000      1.000000        5.603300        2.668000
#
#        acceleration_z        gyro_x        gyro_y        gyro_z
# count    88588.000000  88588.000000  88588.000000  88588.000000
# mean        -0.313956      0.004160      0.037203      0.022327
# std          0.486815      1.253423      1.198725      1.914423
# min         -3.753800     -4.430600     -7.464700     -9.480000
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn
# %matplotlib inline
dataset['acceleration_x'].hist(bins=33)

# %%
#the highest count of acceleration_x was approx. 22000

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn
# %matplotlib inline
dataset['acceleration_y'].hist(bins=33)

# %%
#the highest count of acceleration_y was approx. 15000

# %%
#Normal distribution of wrist

import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt


# Generate some data for this demonstration.
dataset = norm.rvs(0.522170,0.499511, size=500)

# Fit a normal distribution to the data:
mu, std = norm.fit(dataset)

# Plot the histogram.
plt.hist(dataset, bins=25, normed=True, alpha=0.6, color='g')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# %%
#The gaussian distribution shows the data of wrist is normally distributed.
#the standard deviation is 0.49951 and mean value is 0.522170

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('dataset.csv',sep=',')
plt.rcParams['figure.figsize']=(15,9)
sns.boxplot(x="acceleration_x",data=dataset)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import csv
import pandas as pd
import seaborn as sns



dataset = pd.read_csv('dataset.csv',sep=',')
plt.rcParams['figure.figsize']=(15,9)
sns.regplot(x="acceleration_x",y="acceleration_y", data=dataset)

# %%
#The above scatter plot shows many outliers and the rest are strongly connected to each other forming a cluster.
# Here outliers may show some very important information. It has many possible scenarios.

# %%
# %matplotlib inline
import csv
import pandas as pd
import matplotlib.pyplot as plt
dataset  = pd.read_csv("dataset.csv")
dataset.plot()  # plots all columns against index
dataset.plot(kind='scatter',x='acceleration_x',y='acceleration_y') # scatter plot

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='activity',hue='wrist',data=dataset)

# %%
#The above graph shows blue bar as the left wrist and green bar as the right wrist.
#Activity 0 defines people walking and 1 defines people running on the street.
#So, looking at the graph we can conclude that right wrist captured more people running compared to the people walking.

# %%
dataset['gyro_x'].hist(bins=50,figsize=(10,4))

# %%
sns.heatmap(dataset.corr())

# %%
#there is a good coorelation between activity and acceleration_y

# %% [markdown]
# # PART B

# %% [markdown]
# Decision Trees

# %%
dataset.dropna()
# Out:
#              date                time username  wrist  activity  \
# 0      30-06-2017  13:51:15:847724020   viktor      0         0
# 1      30-06-2017  13:51:16:246945023   viktor      0         0
# 2      30-06-2017  13:51:16:446233987   viktor      0         0
# 3      30-06-2017  13:51:16:646117985   viktor      0         0
# 4      30-06-2017  13:51:16:846738994   viktor      0         0
# 5      30-06-2017   13:51:17:46806991   viktor      0         0
# 6      30-06-2017  13:51:17:246767997   viktor      0         0
# 7      30-06-2017  13:51:17:446569025   viktor      0         0
# 8      30-06-2017  13:51:17:646152973   viktor      0         0
# 9      30-06-2017  13:51:17:846502006   viktor      0         0
# 10     30-06-2017   13:51:18:46802997   viktor      0         0
# 11     30-06-2017  13:51:18:246815025   viktor      0         0
# 12     30-06-2017  13:51:18:446740984   viktor      0         0
# 13     30-06-2017  13:51:18:646052002   viktor      0         0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88588 entries, 0 to 88587
# Data columns (total 9 columns):
# username          88588 non-null object
# wrist             88588 non-null int64
# activity          88588 non-null int64
# acceleration_x    88586 non-null float64
# acceleration_y    88585 non-null float64
# acceleration_z    88588 non-null float64
# gyro_x            88588 non-null float64
# gyro_y            88588 non-null float64
# gyro_z            88588 non-null float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 6.1+ MB

# %%
from sklearn import tree
# Create tree object 
model = tree.DecisionTreeClassifier(criterion='gini') # for classification, here you can change the algorithm as gini or entropy (information gain) by default it is gini  
# model = tree.DecisionTreeRegressor() for regression
# Train the model using the training sets and check score
import pandas as pd
from pandas import DataFrame

import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline
sns.set(style='whitegrid', context='notebook')

# %%
X = dataset[['acceleration_x','acceleration_y', 'acceleration_z']]
y = dataset['activity']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
X = X.as_matrix().astype(np.float)
y = y.as_matrix().astype(np.float)

# %%
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-310-720d50661c58> in <module>()
# ----> 1 model.fit(X, y)
#
# C:\Users\Pornima\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     737             sample_weight=sample_weight,
#     738             check_input=check_input,
# --> 739             X_idx_sorted=X_idx_sorted)
#     740         return self
#     741
#
# C:\Users\Pornima\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     120         random_state = check_random_state(self.random_state)
#     121         if check_input:
# --> 122             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     123             y = check_array(y, ensure_2d=False, dtype=None)
#     124             if issparse(X):
#
# ...

# %%
#Accuracy Score
model.score(X, y)

# %% [markdown]
# Naive Bayes Classification

# %%
from sklearn.naive_bayes import GaussianNB
# To calculate the accuracy score of the model
from sklearn.metrics import accuracy_score

# %%
from pandas import read_csv
import numpy
dataset = read_csv('dataset.csv',low_memory=False)
dataset["acceleration_x"].fillna(dataset["acceleration_x"].mean(), inplace=True)
dataset["acceleration_y"].fillna(dataset["acceleration_y"].mean(), inplace=True)
dataset
# Out:
#              date                time username  wrist  activity  \
# 0      30-06-2017  13:51:15:847724020   viktor      0         0
# 1      30-06-2017  13:51:16:246945023   viktor      0         0
# 2      30-06-2017  13:51:16:446233987   viktor      0         0
# 3      30-06-2017  13:51:16:646117985   viktor      0         0
# 4      30-06-2017  13:51:16:846738994   viktor      0         0
# 5      30-06-2017   13:51:17:46806991   viktor      0         0
# 6      30-06-2017  13:51:17:246767997   viktor      0         0
# 7      30-06-2017  13:51:17:446569025   viktor      0         0
# 8      30-06-2017  13:51:17:646152973   viktor      0         0
# 9      30-06-2017  13:51:17:846502006   viktor      0         0
# 10     30-06-2017   13:51:18:46802997   viktor      0         0
# 11     30-06-2017  13:51:18:246815025   viktor      0         0
# 12     30-06-2017  13:51:18:446740984   viktor      0         0
# 13     30-06-2017  13:51:18:646052002   viktor      0         0
# ...

# %%
X = X.as_matrix().astype(np.float)
y = y.as_matrix().astype(np.float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-313-bc5674079ebf> in <module>()
# ----> 1 X = X.as_matrix().astype(np.float)
#       2 y = y.as_matrix().astype(np.float)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'as_matrix'

# %%
gnb = GaussianNB()


# Train our classifier
model = gnb.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-314-8d8867e8d5da> in <module>()
#       3
#       4 # Train our classifier
# ----> 5 model = gnb.fit(X_train, y_train)
#
# C:\Users\Pornima\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     180             Returns self.
#     181         """
# --> 182         X, y = check_X_y(X, y)
#     183         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     184                                  sample_weight=sample_weight)
#
# C:\Users\Pornima\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
preds = gnb.predict(X_test)
print(preds)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-315-74fb375889b8> in <module>()
# ----> 1 preds = gnb.predict(X_test)
#       2 print(preds)
#
# C:\Users\Pornima\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in predict(self, X)
#      63             Predicted target values for X
#      64         """
# ---> 65         jll = self._joint_log_likelihood(X)
#      66         return self.classes_[np.argmax(jll, axis=1)]
#      67
#
# C:\Users\Pornima\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in _joint_log_likelihood(self, X)
#     420
#     421     def _joint_log_likelihood(self, X):
# --> 422         check_is_fitted(self, "classes_")
#     423
#     424         X = check_array(X)
#
# C:\Users\Pornima\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
# ...

# %%
from sklearn.metrics import accuracy_score

# Evaluate accuracy
print(accuracy_score(y_test, preds))

# %%
#88% of accuracy

# %% [markdown]
# Logistic Regression

# %%
dataset.drop('date',axis=1, inplace=True)
dataset.drop('time',axis=1, inplace=True)
dataset.head()
# Out:
#   username  wrist  activity  acceleration_x  acceleration_y  acceleration_z  \
# 0   viktor      0         0          0.2650         -0.7814         -0.0076
# 1   viktor      0         0          0.6722         -1.1233         -0.2344
# 2   viktor      0         0          0.4399         -1.4817          0.0722
# 3   viktor      0         0          0.3031         -0.8125          0.0888
# 4   viktor      0         0          0.4814         -0.9312          0.0359
#
#    gyro_x  gyro_y  gyro_z
# 0 -0.0590  0.0325 -2.9296
# 1 -0.1757  0.0208  0.1269
# 2 -0.9105  0.1063 -2.4367
# 3  0.1199 -0.4099 -2.9336
# 4  0.0527  0.4379  2.4922

# %%
X= dataset.drop('username', axis=1)

y= dataset['activity']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel= LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions=logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     17683
#           1       1.00      1.00      1.00     17753
#
# avg / total       1.00      1.00      1.00     35436

# %%
from sklearn import metrics
y_train = logmodel.predict(X_test)
print("Accuracy score : %s" %metrics.accuracy_score(y_test,y_train))
# Out:
# Accuracy score : 0.999971780111

# %%
X= dataset.drop('username', axis=1)

y= dataset['wrist']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions=logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     16963
#           1       1.00      1.00      1.00     18473
#
# avg / total       1.00      1.00      1.00     35436

# %%
from sklearn import metrics
y_train = logmodel.predict(X_test)
print("Accuracy score : %s" %metrics.accuracy_score(y_test,y_train))
# Out:
# Accuracy score : 0.999971780111

# %%
#Accuracy of 99%

# %% [markdown]
# Lasso Regression

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
from sklearn.linear_model import LassoCV, LassoLarsCV, LassoLarsIC
dataset.head()
# Out:
#   username  wrist  activity  acceleration_x  acceleration_y  acceleration_z  \
# 0   viktor      0         0          0.2650         -0.7814         -0.0076
# 1   viktor      0         0          0.6722         -1.1233         -0.2344
# 2   viktor      0         0          0.4399         -1.4817          0.0722
# 3   viktor      0         0          0.3031         -0.8125          0.0888
# 4   viktor      0         0          0.4814         -0.9312          0.0359
#
#    gyro_x  gyro_y  gyro_z
# 0 -0.0590  0.0325 -2.9296
# 1 -0.1757  0.0208  0.1269
# 2 -0.9105  0.1063 -2.4367
# 3  0.1199 -0.4099 -2.9336
# 4  0.0527  0.4379  2.4922

# %%
X= dataset[['acceleration_x','acceleration_y','acceleration_z']]

y= dataset['wrist']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
dataset = LassoLarsCV(cv=10, precompute= False).fit(X_train,y_train)

# %%
alphas = np.logspace(-4, -1, 10)
scores = np.empty_like(alphas)
for i,a in enumerate(alphas):
    lasso = linear_model.Lasso()
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    scores[i] = lasso.score(X_test, y_test)
    print(a, lasso.coef_)
# Out:
# 0.0001 [-0.31976777 -0.05882803 -0.0253296 ]
# 0.000215443469003 [-0.31934226 -0.05846143 -0.02439974]
# 0.000464158883361 [-0.31842113 -0.05767099 -0.02239142]
# 0.001 [-0.31644649 -0.05596942 -0.01807579]
# 0.00215443469003 [-0.3121859  -0.05230262 -0.00877087]
# 0.00464158883361 [-0.30608884 -0.04478839 -0.        ]
# 0.01 [-0.29807481 -0.02923916 -0.        ]
# 0.0215443469003 [-0.2815555 -0.         0.       ]
# 0.0464158883361 [-0.25692653 -0.          0.        ]
# 0.1 [-0.20386502 -0.          0.        ]

# %%
#Predict Output
predicted= lasso.predict(X_test)
predicted
# Out:
# array([ 0.4040634 ,  0.99302944,  0.53166251, ...,  0.49612884,
#         0.54505644,  0.55200824])

# %%
lasso.score(X, y)
#accuracy_score(predicted, normalize = True)
# Out:
# 0.33249910336010757

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RanFor=RandomForestClassifier(n_estimators=100,random_state=1)

# %%
RanFor.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=1,
#             verbose=0, warm_start=False)

# %%
from sklearn.metrics import *

# %%
accuracy_score(y_test,RanFor.predict(X_test))
# Out:
# 0.9514335703804041

# %%
#Accuracy Score is 95%
